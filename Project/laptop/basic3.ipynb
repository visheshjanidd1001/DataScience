# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df = pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop("warranty",axis=1,inplace=True)

# %%
df.drop("weight",axis=1,inplace=True)

# %%
df.drop("rating",axis=1,inplace=True)

# %%
df.drop("Number of Reviews",axis=1,inplace=True)

# %%
df.drop("Number of Ratings",axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
dt = {
    'Intel' : 1,
    'AMD' : 2,
    'M1' : 3
}

# %%
df['processor_brand'] = df['processor_brand'].map(dt)

# %%
df
# Out:
#       brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS                1        Core i3            10th   4 GB     DDR4
# 1    Lenovo                1        Core i3            10th   4 GB     DDR4
# 2    Lenovo                1        Core i3            10th   4 GB     DDR4
# 3      ASUS                1        Core i5            10th   8 GB     DDR4
# 4      ASUS                1   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...              ...            ...             ...    ...      ...
# 818    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo                2        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dt2 = {
    'Yes' : 1,
    'No' : 0
}

# %%
df['Touchscreen'] = df['Touchscreen'].map(dt2)

# %%
df
# Out:
#       brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS                1        Core i3            10th   4 GB     DDR4
# 1    Lenovo                1        Core i3            10th   4 GB     DDR4
# 2    Lenovo                1        Core i3            10th   4 GB     DDR4
# 3      ASUS                1        Core i5            10th   8 GB     DDR4
# 4      ASUS                1   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...              ...            ...             ...    ...      ...
# 818    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS                2        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo                2        Ryzen 5            10th   8 GB     DDR4
#
# ...
